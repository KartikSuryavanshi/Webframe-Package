# %% [markdown]
# # Testing kartik-webframe Package 🚀
#
# This notebook demonstrates how to use the **kartik-webframe** package - a simple Python library for embedding websites and YouTube videos directly in Jupyter notebooks.
#
# **Package Info:**
# - PyPI: https://pypi.org/project/kartik-webframe/
# - GitHub: https://github.com/KartikSuryavanshi/Webframe-Package
# - Version: 0.1.1

# %% [markdown]
# ## 1. Install the Package
#
# If you haven't installed the package yet, run this cell:

# %%
# Install the package from PyPI
# Uncomment the line below to install
# !pip install kartik-webframe

# %% [markdown]
# ## 2. Import the Package
#
# Import the main functions from the package:

# %%
from webframe import render_site, render_youtube_video

print("✅ Package imported successfully!")

# %% [markdown]
# ## 3. Test Website Embedding
#
# Let's embed some websites directly in the notebook:

# %%
# Example 1: Render Python Documentation
render_site("https://docs.python.org/3/")

# %%
# Example 2: Render GitHub with custom dimensions
render_site("https://github.com", width=1000, height=700)

# %% [markdown]
# ## 4. Test YouTube Video Embedding
#
# Now let's embed some YouTube videos:

# %%
# Example 3: Embed a Python tutorial video
render_youtube_video("https://www.youtube.com/watch?v=rfscVS0vtbw")

# %%
# Example 4: Custom size video
render_youtube_video("https://youtu.be/rfscVS0vtbw", width=1000, height=600)

# %% [markdown]
# ## 5. Test Error Handling
#
# Let's test how the package handles invalid inputs:

# %%
# Test 1: Invalid URL
try:
    render_site("not-a-valid-url")
except Exception as e:
    print(f"✅ Caught expected error: {type(e).__name__}")
    print(f"   Message: {e}")

# %%
# Test 2: Invalid YouTube URL
try:
    render_youtube_video("https://not-youtube.com/watch?v=123")
except Exception as e:
    print(f"✅ Caught expected error: {type(e).__name__}")
    print(f"   Message: {e}")

# %% [markdown]
# ## 6. Summary
#
# ✅ **All tests completed successfully!**
#
# ### What We Tested:
# 1. ✅ Package installation and import
# 2. ✅ Website embedding with default and custom dimensions
# 3. ✅ YouTube video embedding with various URL formats
# 4. ✅ Custom video dimensions
# 5. ✅ Error handling for invalid inputs
#
# ### Package Links:
# - **PyPI:** https://pypi.org/project/kartik-webframe/
# - **GitHub:** https://github.com/KartikSuryavanshi/Webframe-Package
# - **Install:** `pip install kartik-webframe`
#
# ---
#
# **Note:** This package is perfect for:
# - Viewing documentation while coding in Jupyter
# - Embedding tutorial videos in educational notebooks
# - Creating interactive presentations
# - Building data science portfolios
